# %% [markdown]
# # Plot greenspace metrics at multiple spatial scales

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Plot greenspace metrics at 100m

# %%
# read GeoJSON containing greenspace metrics at 100m within GM
gdf_100_gm = gpd.read_file("thesis_project/output/dataframes/greenspace_metrics_100_df.json")
gdf_100_gm.head()
# Out:
#    NDVI_100  Greenspace%_100  Canopy%_100  Grass%_100  Shrubs%_100  \
# 0  0.536433         0.414039     0.201814    0.097506     0.106576
# 1  0.571965         0.551457     0.108844    0.072562     0.340136
# 2  0.455587         0.256395     0.129252    0.092971     0.043084
# 3  0.816160         0.942891     0.009070    0.249433     0.068027
# 4  0.526997         0.388459     0.217687    0.061224     0.111111
#
#                         geometry
# 0  POINT (377971.171 402346.176)
# 1  POINT (364310.461 403435.100)
# 2  POINT (369566.841 406840.228)
# 3  POINT (354567.818 412168.416)
# 4  POINT (388526.382 403175.927)

# %% [markdown]
# ### 1.1. NDVI vs. Greenspace%

# %%
# plot NDVI vs. Greenspace% within GM
ndvi_green_100_plot = sns.lmplot(x="NDVI_100", y="Greenspace%_100", data=gdf_100_gm, 
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_green_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_green_100_plot.png")

# %% [markdown]
# ### 1.2. NDVI vs. Canopy%

# %%
# plot NDVI vs. Canopy% only points within GM
ndvi_canopy_100_plot = sns.lmplot(x="NDVI_100", y="Canopy%_100", data=gdf_100_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_canopy_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_canopy_100_plot.png")

# %% [markdown]
# ### 1.3. NDVI vs. Grass%

# %%
# plot NDVI vs. Canopy% only points within GM
ndvi_grass_100_plot = sns.lmplot(x="NDVI_100", y="Grass%_100", data=gdf_100_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_grass_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_grass_100_plot.png")

# %% [markdown]
# ### 1.4. NDVI vs. Shrubs%

# %%
# plot NDVI vs. Shrubs% 
ndvi_shrubs_100_plot = sns.lmplot(x="NDVI_100", y="Shrubs%_100", data=gdf_100_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_shrubs_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_shrubs_100_plot.png")

# %% [markdown]
# ## 2. Plot greenspace metrics at 300m

# %%
# read GeoJSON containing greenspace metrics at 300m within GM
gdf_300_gm = gpd.read_file("thesis_project/output/dataframes/greenspace_metrics_300_df.json")
gdf_300_gm.head()
# Out:
#    NDVI_300  Greenspace%_300   Canopy%_300  Grass%_300  Shrubs%_300  \
# 0  0.488255         0.955836  2.242873e-16    0.062290     0.421350
# 1  0.531893         0.496460  2.145669e-01    0.128283     0.198172
# 2  0.812246         0.932001  4.007312e-01    0.247811     0.353859
# 3  0.949025         0.989765  4.611924e-02    0.185859     0.605270
# 4  0.562222         0.574693  3.180540e-01    0.167677     0.148158
#
#                         geometry
# 0  POINT (396607.971 420663.294)
# 1  POINT (357230.295 401556.298)
# 2  POINT (390380.102 385914.240)
# 3  POINT (374281.691 415010.143)
# 4  POINT (389574.066 388155.085)

# %% [markdown]
# ### 2.1. NDVI vs. Greenspace%

# %%
# plot NDVI vs. Greenspace% within GM
ndvi_green_300_plot = sns.lmplot(x="NDVI_300", y="Greenspace%_300", data=gdf_300_gm, 
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_green_300_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_green_300_plot.png")

# %% [markdown]
# ### 2.2. NDVI vs. Canopy%

# %%
# plot NDVI vs. Canopy% within GM
ndvi_canopy_300_plot = sns.lmplot(x="NDVI_300", y="Canopy%_300", data=gdf_300_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_canopy_300_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_canopy_300_plot.png")

# %% [markdown]
# ### 2.3. NDVI vs. Grass%

# %%
# plot NDVI vs. Grass% within GM
ndvi_grass_300_plot = sns.lmplot(x="NDVI_300", y="Grass%_300", data=gdf_300_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_grass_300_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_grass_300_plot.png")

# %% [markdown]
# ### 2.4. NDVI vs. Shrubs%

# %%
# plot NDVI vs. Shrubs% within GM
ndvi_shrubs_300_plot = sns.lmplot(x="NDVI_300", y="Shrubs%_300", data=gdf_300_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_shrubs_300_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_shrubs_300_plot.png")

# %% [markdown]
# ## 3. Plot greenspace metrics at 500m

# %%
# read GeoJSON containing greenspace metrics at 500m within GM
gdf_500_gm = gpd.read_file("thesis_project/output/dataframes/greenspace_metrics_500_df.json")
gdf_500_gm.head()
# Out:
#    NDVI_500  Greenspace%_500  Canopy%_500  Grass%_500  Shrubs%_500  \
# 0  0.616906         0.714233     0.509538    0.305474     0.177276
# 1  0.535196         0.518279     0.272543    0.170375     0.244285
# 2  0.625744         0.665035     0.458237    0.265076     0.194620
# 3  0.869751         0.959438     0.194798    0.637881     0.401261
# 4  0.855770         0.984456     0.180780    0.170082     0.213244
#
#                         geometry
# 0  POINT (377098.736 391409.893)
# 1  POINT (388776.738 395338.550)
# 2  POINT (385102.497 389586.914)
# 3  POINT (358860.328 409008.505)
# 4  POINT (369877.609 414278.479)

# %% [markdown]
# ### 3.1. NDVI vs. Greenspace%

# %%
# plot NDVI vs. Greenspace% within GM
ndvi_green_500_plot = sns.lmplot(x="NDVI_500", y="Greenspace%_500", data=gdf_500_gm, 
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_green_500_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_green_500_plot.png")

# %% [markdown]
# ### 3.2. NDVI vs. Canopy%

# %%
# plot NDVI vs. Canopy% within GM
ndvi_canopy_500_plot = sns.lmplot(x="NDVI_500", y="Canopy%_500", data=gdf_500_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_canopy_500_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_canopy_500_plot.png")

# %% [markdown]
# ### 3.3. NDVI vs. Grass%

# %%
# plot NDVI vs. Grass% within GM
ndvi_grass_500_plot = sns.lmplot(x="NDVI_500", y="Grass%_500", data=gdf_500_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_grass_500_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_grass_500_plot.png")

# %% [markdown]
# ### 3.4. NDVI vs. Shrubs%

# %%
# plot NDVI vs. Shrubs% within GM
ndvi_shrubs_500_plot = sns.lmplot(x="NDVI_500", y="Shrubs%_500", data=gdf_500_gm,
          scatter_kws={"color": "forestgreen"}, line_kws={'color': 'black'})

# %%
# save plot into png file
fig = ndvi_shrubs_500_plot.fig
fig.savefig("thesis_project/visualizations/eda/ndvi_shrubs_500_plot.png")

# %% [markdown]
# ## 4. Density plot greenspace metrics at 100m

# %% [markdown]
# ### 4.1. NDVI

# %%
# density plot NDVI_100
density_ndvi_100_plot = sns.displot(gdf_100_gm, x="NDVI_100")

# %%
# save plot into png file
fig = density_ndvi_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/density_ndvi_100_plot.png")

# %% [markdown]
# ### 4.2. Greenspace%

# %%
# density plot Greenspace%_100
density_green_100_plot = sns.displot(gdf_100_gm, x="Greenspace%_100")

# %%
# save plot into png file
fig = density_green_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/density_green_100_plot.png")

# %% [markdown]
# ### 4.2. Canopy%

# %%
# density plot Canopy%_100
density_canopy_100_plot = sns.displot(gdf_100_gm, x="Canopy%_100")

# %%
# save plot into png file
fig = density_canopy_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/density_canopy_100_plot.png")

# %% [markdown]
# ### 4.3. Grass%

# %%
# density plot Grass%_100
density_grass_100_plot = sns.displot(gdf_100_gm, x="Grass%_100")

# %%
# save plot into png file
fig = density_grass_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/density_grass_100_plot.png")

# %% [markdown]
# ### 4.4. Shrubs%

# %%
# density plot Shrubs%_100
density_shrubs_100_plot = sns.displot(gdf_100_gm, x="Shrubs%_100")

# %%
# save plot into png file
fig = density_shrubs_100_plot.fig
fig.savefig("thesis_project/visualizations/eda/density_shrubs_100_plot.png")

# %% [markdown]
# ## 5. Density plot greenspace metrics at 300m

# %%
# density plot NDVI_300
sns.displot(gdf_300_gm, x="NDVI_300")

# %%
# density plot Greenspace%_300
sns.displot(gdf_300_gm, x="Greenspace%_300")

# %%
# density plot Canopy%_300
sns.displot(gdf_300_gm, x="Canopy%_300")

# %%
# density plot Grass%_300
sns.displot(gdf_300_gm, x="Grass%_300")

# %%
# density plot Shrubs%_300
sns.displot(gdf_300_gm, x="Shrubs%_300")

# %% [markdown]
# ## 6. Density plot greenspace metrics at 500m

# %%
# density plot NDVI_500
sns.displot(gdf_500_gm, x="NDVI_500")

# %%
# density plot Greenspace%_500
sns.displot(gdf_500_gm, x="Greenspace%_500")

# %%
# density plot Canopy%_500
sns.displot(gdf_500_gm, x="Canopy%_500")

# %%
# density plot Grass%_500
sns.displot(gdf_500_gm, x="Grass%_500")

# %%
# density plot Shrubs%_500
sns.displot(gdf_500_gm, x="Shrubs%_500")

# %% [markdown]
# ## 5. Descriptive statistics

# %% [markdown]
# ### 5.1. 100 meters

# %%
# mean
gdf_100_gm.mean()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/3596133968.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_100_gm.mean()
# NDVI_100           0.703096
# Greenspace%_100    0.718071
# Canopy%_100        0.203500
# Grass%_100         0.167059
# Shrubs%_100        0.343169
# dtype: float64

# %%
# median
gdf_100_gm.median()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/1055657670.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_100_gm.median()
# NDVI_100           0.704443
# Greenspace%_100    0.794170
# Canopy%_100        0.165533
# Grass%_100         0.111111
# Shrubs%_100        0.242630
# dtype: float64

# %%
# standard deviation
gdf_100_gm.std()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/715444628.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_100_gm.std()
# NDVI_100           0.147320
# Greenspace%_100    0.276110
# Canopy%_100        0.178001
# Grass%_100         0.173571
# Shrubs%_100        0.281763
# dtype: float64

# %%
# skewness
pd.DataFrame(gdf_100_gm).skew()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/3359276365.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(gdf_100_gm).skew()
# NDVI_100          -0.321840
# Greenspace%_100   -0.711273
# Canopy%_100        1.259254
# Grass%_100         1.848943
# Shrubs%_100        0.968476
# dtype: float64

# %%
# kurtosis
pd.DataFrame(gdf_100_gm).kurtosis()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/2539175451.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(gdf_100_gm).kurtosis()
# NDVI_100          -0.468762
# Greenspace%_100   -0.649340
# Canopy%_100        1.722329
# Grass%_100         3.644903
# Shrubs%_100       -0.175506
# dtype: float64

# %% [markdown]
# ### 5.2. 300 meters

# %%
# mean
gdf_300_gm.mean()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/1380955507.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_300_gm.mean()
# NDVI_300           0.624495
# Greenspace%_300    0.705947
# Canopy%_300        0.210290
# Grass%_300         0.204565
# Shrubs%_300        0.336755
# dtype: float64

# %%
# median
gdf_300_gm.median()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/2327808779.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_300_gm.median()
# NDVI_300           0.624340
# Greenspace%_300    0.746442
# Canopy%_300        0.193195
# Grass%_300         0.167340
# Shrubs%_300        0.259613
# dtype: float64

# %%
# standard deviation
gdf_300_gm.std()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/890668579.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_300_gm.std()
# NDVI_300           0.164366
# Greenspace%_300    0.241343
# Canopy%_300        0.138333
# Grass%_300         0.150400
# Shrubs%_300        0.239829
# dtype: float64

# %%
# skewness
pd.DataFrame(gdf_300_gm).skew()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/717706031.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(gdf_300_gm).skew()
# NDVI_300          -0.298257
# Greenspace%_300   -0.582672
# Canopy%_300        0.732007
# Grass%_300         1.434370
# Shrubs%_300        1.134135
# dtype: float64

# %%
# kurtosis
pd.DataFrame(gdf_300_gm).kurtosis()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/1267028561.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(gdf_300_gm).kurtosis()
# NDVI_300          -0.329672
# Greenspace%_300   -0.658334
# Canopy%_300        0.741007
# Grass%_300         2.543125
# Shrubs%_300        0.532011
# dtype: float64

# %% [markdown]
# ### 5.3. 500 meters

# %%
# mean
gdf_500_gm.mean()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/3151633392.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_500_gm.mean()
# NDVI_500           0.633488
# Greenspace%_500    0.698370
# Canopy%_500        0.298131
# Grass%_500         0.243275
# Shrubs%_500        0.330095
# dtype: float64

# %%
# median
gdf_500_gm.median()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/440012443.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_500_gm.median()
# NDVI_500           0.638316
# Greenspace%_500    0.728639
# Canopy%_500        0.282009
# Grass%_500         0.214871
# Shrubs%_500        0.262909
# dtype: float64

# %%
# standard deviation
gdf_500_gm.std()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/2473735971.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gdf_500_gm.std()
# NDVI_500           0.171889
# Greenspace%_500    0.224477
# Canopy%_500        0.171074
# Grass%_500         0.146521
# Shrubs%_500        0.221178
# dtype: float64

# %%
# skewness
pd.DataFrame(gdf_500_gm).skew()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/4020229813.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(gdf_500_gm).skew()
# NDVI_500          -0.338523
# Greenspace%_500   -0.549747
# Canopy%_500        0.435436
# Grass%_500         1.070716
# Shrubs%_500        1.221706
# dtype: float64

# %%
# kurtosis
pd.DataFrame(gdf_500_gm).kurtosis()
# Out:
# /var/folders/6g/kgz5rml118s6lqw25w5sv5mr0000gn/T/ipykernel_1651/3508897956.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(gdf_500_gm).kurtosis()
# NDVI_500          -0.122428
# Greenspace%_500   -0.530268
# Canopy%_500        0.155473
# Grass%_500         1.530198
# Shrubs%_500        0.914055
# dtype: float64
